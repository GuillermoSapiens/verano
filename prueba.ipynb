# %% [markdown]
# # TALLER VERANO CGEO
# ###### Guillermo Alberto Sapiens Peiro

# %%
Pkg.installed()
# Out:
# Dict{String,VersionNumber} with 31 entries:
#   "PDMats"            => v"0.6.0"
#   "Distributions"     => v"0.13.0"
#   "Rmath"             => v"0.1.6"
#   "SortingAlgorithms" => v"0.1.1"
#   "FixedPointNumbers" => v"0.3.8"
#   "Conda"             => v"0.5.3"
#   "SHA"               => v"0.3.3"
#   "PyCall"            => v"1.12.0"
#   "LaTeXStrings"      => v"0.2.1"
#   "ZMQ"               => v"0.4.3"
#   "JSON"              => v"0.12.0"
#   "StatsBase"         => v"0.15.0"
#   "DataArrays"        => v"0.4.1"
#   "ColorTypes"        => v"0.5.1"
#   "Compat"            => v"0.25.2"
#   "DataStructures"    => v"0.5.3"
#   "IJulia"            => v"1.5.0"
#   "PyPlot"            => v"2.3.2"
#   "Calculus"          => v"0.2.2"
#   "Colors"            => v"0.7.3"
#   "GZip"              => v"0.3.0"
#   "MbedTLS"           => v"0.4.5"
#   "MacroTools"        => v"0.3.6"
#   "FileIO"            => v"0.3.1"
#   "QuadGK"            => v"0.1.2"
#   ⋮                   => ⋮

# %%
Pkg.add("PyPlot")
# Out:
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of PyPlot
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
using PyPlot

# %%
ra=rand(1000)
plot(ra,"b")
xlabel("INDEX")
ylabel("Rand")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f1d30bac890>)
# PyObject <matplotlib.text.Text object at 0x7f1d308fb7d0>
